# %% [markdown]
# <a href="https://colab.research.google.com/github/MarouaneAyech/ML/blob/master/CV/create_db.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2>Build an image database</h2>

# %%
from pathlib import Path
db_path="player-faces-db"
db_dir = Path(db_path)
print(db_dir.absolute())
# Out:
# C:\Users\marouane\Desktop\ML\17-10-19\MLRW\ML\CV\player-faces-db

# %%
folders = [folder for folder in db_dir.iterdir() if folder.is_dir()]
for folder in folders:
    print(folder)
# Out:
# player-faces-db\messi
# player-faces-db\ronaldo
# player-faces-db\salah

# %%
from skimage.io import imread
import matplotlib.pyplot as plt

i=0
plt.figure(figsize=(40,10))
for class_id, folder in enumerate(folders):
    for file in folder.iterdir():
        img = imread(file)
        plt.subplot(3,20,i+1)
        i += 1
        plt.imshow(img)
        plt.axis('off')
plt.show()
